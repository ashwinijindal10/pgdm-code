# %%
#import tensorflow as tf; 
#print(tf.__version__)

#Cuda compilation tools, release 11.0, V11.0.194

import matplotlib.pyplot as plt

def plot_image(images, captions=None, cmap=None ):
    f, axes = plt.subplots(1, len(images), sharey=True)
    f.set_figwidth(15)
    for ax,image,caption in zip(axes, images, captions):
        ax.imshow(image, cmap)
        ax.set_title(caption)

# %%
import cv2 
import pytesseract
from pytesseract import Output

img = cv2.imread('img/tobetexted5.jpg')
img1 = img.copy()
#img = cv2.fastNlMeansDenoisingColored(img, None, 4, 4, 7, 21)
#plt.imshow(img)
#preprocess  https://nanonets.com/blog/ocr-with-tesseract/
img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#img = cv2.Canny(img, 90, 100)
#img=cv2.resize(img,(200,100), interpolation = cv2.INTER_LANCZOS4 )

plt.imshow(img)

#print(img)
#img=cv2.medianBlur(img,5)
#cv2.threshold(crop_img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]
#_, img = cv2.threshold(img,150,255,cv2.THRESH_BINARY)


pytesseract.pytesseract.tesseract_cmd = 'C://Program Files//Tesseract-OCR//tesseract.exe'
#configuration = ("-l eng --oem 1 --psm 8")
pytesseract.image_to_string(img, config=configuration)

#cv2.imshow('img', img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()3

#observation - proper sizing matter quality of reading
# Out:
# 'pealiereesit ee'

# %%
d = pytesseract.image_to_data(img, output_type=Output.DICT)
print(d['text'])
n_boxes = len(d['text'])
for i in range(n_boxes):
    if int(d['conf'][i]) > 60:
        (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
        img = cv2.rectangle(img1, (x, y), (x + w, y + h), (0, 255, 0), 2)

plt.imshow(img1)
#cv2.imshow('img', img)
#cv2.waitKey(0)
# Out:
# ['']

# %%
#image to text
import numpy as np
np.set_printoptions(threshold=np.inf)

img = cv2.imread('img/tobetexted.jpg')
#img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#_, img = cv2.threshold(img,200,255,cv2.THRESH_BINARY)
img = cv2.Canny(img, 90, 100)
plt.imshow(img)

pytesseract.pytesseract.tesseract_cmd = 'C://Program Files//Tesseract-OCR//tesseract.exe'
configuration = ("-l eng --oem 1 --psm 8")
pytesseract.image_to_string(img, config=configuration)


#print(img)
# Out:
# 'Nscmmectine'
