# %%
import cv2
import numpy as np

hand_hist = None
traverse_point = []
total_rectangle = 9
hand_rect_one_x = None
hand_rect_one_y = None

hand_rect_two_x = None
hand_rect_two_y = None


def rescale_frame(frame, wpercent=130, hpercent=130):
    width = int(frame.shape[1] * wpercent / 100)
    height = int(frame.shape[0] * hpercent / 100)
    return cv2.resize(frame, (width, height), interpolation=cv2.INTER_AREA)


def contours(hist_mask_image):
    gray_hist_mask_image = cv2.cvtColor(hist_mask_image, cv2.COLOR_BGR2GRAY)
    ret, thresh = cv2.threshold(gray_hist_mask_image, 0, 255, 0)
    cont, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    return cont

def draw_rect(frame):
    rows, cols, _ = frame.shape
    global total_rectangle, hand_rect_one_x, hand_rect_one_y, hand_rect_two_x, hand_rect_two_y

    hand_rect_one_x = np.array(
        [6 * rows / 20, 6 * rows / 20, 6 * rows / 20, 9 * rows / 20, 9 * rows / 20, 9 * rows / 20, 12 * rows / 20,
         12 * rows / 20, 12 * rows / 20], dtype=np.uint32)

    hand_rect_one_y = np.array(
        [9 * cols / 20, 10 * cols / 20, 11 * cols / 20, 9 * cols / 20, 10 * cols / 20, 11 * cols / 20, 9 * cols / 20,
         10 * cols / 20, 11 * cols / 20], dtype=np.uint32)

    hand_rect_two_x = hand_rect_one_x + 10
    hand_rect_two_y = hand_rect_one_y + 10

    for i in range(total_rectangle):
        cv2.rectangle(frame, (hand_rect_one_y[i], hand_rect_one_x[i]),
                      (hand_rect_two_y[i], hand_rect_two_x[i]),
                      (0, 255, 0), 1)

    return frame


def hand_histogram(frame):
    global hand_rect_one_x, hand_rect_one_y

    hsv_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    roi = np.zeros([90, 10, 3], dtype=hsv_frame.dtype)

    for i in range(total_rectangle):
        roi[i * 10: i * 10 + 10, 0: 10] = hsv_frame[hand_rect_one_x[i]:hand_rect_one_x[i] + 10,
                                          hand_rect_one_y[i]:hand_rect_one_y[i] + 10]

    hand_hist = cv2.calcHist([roi], [0, 1], None, [180, 256], [0, 180, 0, 256])
    return cv2.normalize(hand_hist, hand_hist, 0, 255, cv2.NORM_MINMAX)


def hist_masking(frame, hist):
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    dst = cv2.calcBackProject([hsv], [0, 1], hist, [0, 180, 0, 256], 1)

    disc = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (31, 31))
    cv2.filter2D(dst, -1, disc, dst)

    ret, thresh = cv2.threshold(dst, 150, 255, cv2.THRESH_BINARY)

    # thresh = cv2.dilate(thresh, None, iterations=5)

    thresh = cv2.merge((thresh, thresh, thresh))

    return cv2.bitwise_and(frame, thresh)


def centroid(max_contour):
    moment = cv2.moments(max_contour)
    if moment['m00'] != 0:
        cx = int(moment['m10'] / moment['m00'])
        cy = int(moment['m01'] / moment['m00'])
        return cx, cy
    else:
        return None


def farthest_point(defects, contour, centroid):
    if defects is not None and centroid is not None:
        s = defects[:, 0][:, 0]
        cx, cy = centroid

        x = np.array(contour[s][:, 0][:, 0], dtype=np.float)
        y = np.array(contour[s][:, 0][:, 1], dtype=np.float)

        xp = cv2.pow(cv2.subtract(x, cx), 2)
        yp = cv2.pow(cv2.subtract(y, cy), 2)
        dist = cv2.sqrt(cv2.add(xp, yp))

        dist_max_i = np.argmax(dist)

        if dist_max_i < len(s):
            farthest_defect = s[dist_max_i]
            farthest_point = tuple(contour[farthest_defect][0])
            return farthest_point
        else:
            return None


def draw_circles(frame, traverse_point):
    if traverse_point is not None:
        for i in range(len(traverse_point)):
            cv2.circle(frame, traverse_point[i], int(5 - (5 * i * 3) / 100), [0, 255, 255], -1)


def manage_image_opr(frame, hand_hist):
    hist_mask_image = hist_masking(frame, hand_hist)

    hist_mask_image = cv2.erode(hist_mask_image, None, iterations=2)
    hist_mask_image = cv2.dilate(hist_mask_image, None, iterations=2)

    contour_list = contours(hist_mask_image)
    max_cont = max(contour_list, key=cv2.contourArea)

    cnt_centroid = centroid(max_cont)
    cv2.circle(frame, cnt_centroid, 5, [255, 0, 255], -1)

    if max_cont is not None:
        hull = cv2.convexHull(max_cont, returnPoints=False)
        defects = cv2.convexityDefects(max_cont, hull)
        far_point = farthest_point(defects, max_cont, cnt_centroid)
        print("Centroid : " + str(cnt_centroid) + ", farthest Point : " + str(far_point))
        cv2.circle(frame, far_point, 5, [0, 0, 255], -1)
        if len(traverse_point) < 20:
            traverse_point.append(far_point)
        else:
            traverse_point.pop(0)
            traverse_point.append(far_point)

        draw_circles(frame, traverse_point)


def main():
    global hand_hist
    is_hand_hist_created = False
    capture = cv2.VideoCapture(0)

    while capture.isOpened():
        pressed_key = cv2.waitKey(1)
        _, frame = capture.read()
        frame = cv2.flip(frame, 1)

        if pressed_key & 0xFF == ord('z'):
            is_hand_hist_created = True
            hand_hist = hand_histogram(frame)

        if is_hand_hist_created:
            manage_image_opr(frame, hand_hist)

        else:
            frame = draw_rect(frame)

        cv2.imshow("Live Feed", rescale_frame(frame))

        if pressed_key == 27:
            break

    cv2.destroyAllWindows()
    capture.release()


main()
# Out:
# Centroid : (297, 188), farthest Point : (172, 374)
# Centroid : (298, 186), farthest Point : (241, 412)
# Centroid : (302, 185), farthest Point : (199, 415)
# Centroid : (304, 181), farthest Point : (178, 362)
# Centroid : (302, 191), farthest Point : (205, 410)
# Centroid : (303, 190), farthest Point : (226, 416)
# Centroid : (306, 186), farthest Point : (200, 414)
# Centroid : (305, 188), farthest Point : (238, 414)
# Centroid : (304, 189), farthest Point : (172, 363)
# Centroid : (304, 186), farthest Point : (218, 413)
# Centroid : (304, 186), farthest Point : (206, 414)
# Centroid : (304, 189), farthest Point : (222, 410)
# Centroid : (305, 192), farthest Point : (207, 414)
# Centroid : (302, 193), farthest Point : (198, 414)
# Centroid : (306, 188), farthest Point : (235, 415)
# Centroid : (307, 194), farthest Point : (209, 408)
# Centroid : (306, 193), farthest Point : (185, 0)
# Centroid : (308, 185), farthest Point : (173, 373)
# Centroid : (308, 200), farthest Point : (132, 364)
# Centroid : (307, 197), farthest Point : (206, 410)
# Centroid : (311, 195), farthest Point : (240, 413)
# Centroid : (310, 189), farthest Point : (175, 372)
# Centroid : (314, 198), farthest Point : (222, 411)
# Centroid : (309, 201), farthest Point : (216, 412)
# Centroid : (312, 199), farthest Point : (176, 367)
# Centroid : (309, 213), farthest Point : (228, 0)
# Centroid : (306, 210), farthest Point : (176, 394)
# Centroid : (304, 207), farthest Point : (204, 404)
# Centroid : (307, 211), farthest Point : (235, 0)
# Centroid : (304, 215), farthest Point : (233, 0)
# Centroid : (295, 209), farthest Point : (208, 0)
# Centroid : (299, 208), farthest Point : (250, 0)
# Centroid : (298, 206), farthest Point : (202, 410)
# Centroid : (298, 203), farthest Point : (226, 412)
# Centroid : (308, 201), farthest Point : (222, 391)
# Centroid : (307, 201), farthest Point : (403, 369)
# Centroid : (305, 198), farthest Point : (173, 369)
# Centroid : (300, 206), farthest Point : (176, 368)
# Centroid : (305, 204), farthest Point : (272, 14)
# Centroid : (299, 191), farthest Point : (179, 3)
# Centroid : (297, 192), farthest Point : (178, 0)
# Centroid : (301, 211), farthest Point : (235, 413)
# Centroid : (303, 200), farthest Point : (190, 355)
# Centroid : (304, 205), farthest Point : (169, 365)
# Centroid : (297, 197), farthest Point : (153, 4)
# Centroid : (303, 210), farthest Point : (303, 29)
# Centroid : (292, 211), farthest Point : (223, 410)
# Centroid : (293, 210), farthest Point : (249, 37)
# Centroid : (286, 220), farthest Point : (221, 391)
# Centroid : (276, 235), farthest Point : (221, 59)
# Centroid : (278, 229), farthest Point : (205, 414)
# Centroid : (268, 254), farthest Point : (189, 81)
# Centroid : (271, 258), farthest Point : (181, 94)
# Centroid : (274, 264), farthest Point : (171, 100)
# Centroid : (274, 261), farthest Point : (138, 71)
# Centroid : (274, 265), farthest Point : (227, 413)
# Centroid : (279, 276), farthest Point : (424, 332)
# Centroid : (272, 271), farthest Point : (162, 112)
# Centroid : (275, 284), farthest Point : (170, 125)
# Centroid : (271, 298), farthest Point : (165, 147)
# Centroid : (280, 309), farthest Point : (159, 173)
# Centroid : (277, 316), farthest Point : (431, 383)
# Centroid : (283, 344), farthest Point : (438, 386)
# Centroid : (224, 249), farthest Point : (163, 367)
# Centroid : (224, 252), farthest Point : (166, 368)
# Centroid : (229, 247), farthest Point : (233, 367)
# Centroid : (222, 256), farthest Point : (139, 356)
# Centroid : (256, 296), farthest Point : (358, 386)
# Centroid : (274, 299), farthest Point : (441, 378)
# Centroid : (275, 299), farthest Point : (433, 375)
# Centroid : (277, 297), farthest Point : (439, 381)
# Centroid : (273, 302), farthest Point : (433, 378)
# Centroid : (277, 300), farthest Point : (433, 371)
# Centroid : (273, 300), farthest Point : (433, 372)
# Centroid : (270, 297), farthest Point : (440, 380)
# Centroid : (275, 294), farthest Point : (433, 378)
# Centroid : (276, 300), farthest Point : (436, 373)
# Centroid : (277, 294), farthest Point : (436, 368)
# Centroid : (280, 296), farthest Point : (437, 369)
# Centroid : (279, 295), farthest Point : (433, 359)
# Centroid : (282, 288), farthest Point : (436, 357)
# Centroid : (279, 291), farthest Point : (435, 360)
# Centroid : (281, 289), farthest Point : (434, 361)
# Centroid : (278, 294), farthest Point : (429, 359)
# Centroid : (284, 294), farthest Point : (436, 362)
# Centroid : (279, 291), farthest Point : (433, 358)
# Centroid : (279, 296), farthest Point : (433, 358)
# Centroid : (279, 293), farthest Point : (434, 359)
# Centroid : (280, 292), farthest Point : (433, 348)
# Centroid : (282, 294), farthest Point : (436, 365)
# Centroid : (280, 295), farthest Point : (435, 362)
# Centroid : (283, 294), farthest Point : (434, 360)
# Centroid : (278, 294), farthest Point : (437, 359)
# Centroid : (277, 296), farthest Point : (436, 361)
# Centroid : (279, 293), farthest Point : (434, 360)
# Centroid : (283, 296), farthest Point : (432, 356)
# Centroid : (279, 289), farthest Point : (434, 360)
# Centroid : (278, 293), farthest Point : (433, 361)
# Centroid : (276, 294), farthest Point : (433, 357)
# Centroid : (280, 288), farthest Point : (435, 359)
# Centroid : (281, 296), farthest Point : (434, 351)
# Centroid : (276, 294), farthest Point : (434, 354)
# Centroid : (278, 289), farthest Point : (434, 351)
# Centroid : (282, 287), farthest Point : (440, 357)
# Centroid : (280, 289), farthest Point : (432, 356)
# Centroid : (273, 291), farthest Point : (124, 377)
# Centroid : (273, 291), farthest Point : (124, 377)
# Centroid : (275, 289), farthest Point : (172, 156)
# Centroid : (278, 281), farthest Point : (160, 161)
# Centroid : (276, 282), farthest Point : (154, 166)
# Centroid : (275, 281), farthest Point : (156, 159)
# Centroid : (276, 282), farthest Point : (156, 158)
# Centroid : (271, 284), farthest Point : (164, 151)
# Centroid : (277, 281), farthest Point : (171, 148)
# Centroid : (272, 283), farthest Point : (444, 326)
# Centroid : (285, 272), farthest Point : (215, 119)
# Centroid : (281, 259), farthest Point : (449, 300)
# Centroid : (288, 260), farthest Point : (446, 286)
# Centroid : (288, 260), farthest Point : (446, 286)
# Centroid : (238, 255), farthest Point : (230, 409)
# Centroid : (242, 269), farthest Point : (217, 412)
# Centroid : (237, 261), farthest Point : (236, 394)
# Centroid : (235, 251), farthest Point : (239, 367)
# Centroid : (235, 254), farthest Point : (238, 368)
# Centroid : (232, 264), farthest Point : (245, 410)
# Centroid : (241, 269), farthest Point : (200, 414)
# Centroid : (236, 262), farthest Point : (213, 407)
# Centroid : (240, 258), farthest Point : (171, 376)
# Centroid : (237, 259), farthest Point : (172, 384)
# Centroid : (240, 259), farthest Point : (242, 394)
# Centroid : (241, 268), farthest Point : (252, 414)
# Centroid : (240, 253), farthest Point : (253, 393)
# Centroid : (240, 256), farthest Point : (156, 372)
# Centroid : (245, 254), farthest Point : (224, 392)
# Centroid : (237, 258), farthest Point : (139, 360)
# Centroid : (242, 247), farthest Point : (244, 366)
# Centroid : (232, 263), farthest Point : (230, 410)
# Centroid : (233, 265), farthest Point : (244, 413)
# Centroid : (246, 268), farthest Point : (219, 409)
# Centroid : (232, 266), farthest Point : (133, 376)
# Centroid : (232, 266), farthest Point : (133, 376)
# Centroid : (245, 255), farthest Point : (218, 407)
# Centroid : (239, 269), farthest Point : (157, 373)
# Centroid : (243, 261), farthest Point : (242, 397)
# Centroid : (237, 268), farthest Point : (250, 411)
# Centroid : (239, 262), farthest Point : (234, 410)
# Centroid : (241, 257), farthest Point : (159, 368)
# Centroid : (240, 265), farthest Point : (249, 412)
# Centroid : (223, 264), farthest Point : (231, 389)
# Centroid : (242, 255), farthest Point : (230, 393)
# Centroid : (242, 263), farthest Point : (241, 407)
# Centroid : (236, 258), farthest Point : (175, 357)
# Centroid : (236, 258), farthest Point : (175, 357)
# Centroid : (238, 261), farthest Point : (255, 412)
# Centroid : (239, 277), farthest Point : (134, 380)
# Centroid : (248, 270), farthest Point : (218, 407)
# Centroid : (231, 270), farthest Point : (239, 410)
# Centroid : (236, 263), farthest Point : (255, 413)
# Centroid : (241, 267), farthest Point : (157, 379)
# Centroid : (246, 262), farthest Point : (154, 366)
# Centroid : (248, 257), farthest Point : (214, 402)
# Centroid : (245, 263), farthest Point : (154, 367)
# Centroid : (240, 267), farthest Point : (257, 414)
# Centroid : (246, 258), farthest Point : (255, 397)
# Centroid : (246, 258), farthest Point : (255, 397)
# Centroid : (247, 268), farthest Point : (245, 413)
# Centroid : (231, 266), farthest Point : (242, 395)
# Centroid : (248, 275), farthest Point : (230, 412)
# Centroid : (236, 275), farthest Point : (132, 378)
# Centroid : (243, 270), farthest Point : (166, 390)
# Centroid : (246, 264), farthest Point : (234, 409)
# Centroid : (244, 256), farthest Point : (181, 350)
# Centroid : (238, 256), farthest Point : (119, 258)
# Centroid : (237, 257), farthest Point : (177, 371)
# Centroid : (243, 272), farthest Point : (131, 375)
# Centroid : (243, 272), farthest Point : (131, 375)
# Centroid : (245, 257), farthest Point : (244, 368)
# Centroid : (233, 267), farthest Point : (181, 385)
# Centroid : (244, 256), farthest Point : (176, 373)
# Centroid : (239, 262), farthest Point : (307, 376)
# Centroid : (245, 273), farthest Point : (249, 414)
# Centroid : (235, 268), farthest Point : (252, 415)
# Centroid : (251, 249), farthest Point : (231, 366)
# Centroid : (240, 270), farthest Point : (166, 391)
# Centroid : (235, 264), farthest Point : (132, 378)
# Centroid : (252, 258), farthest Point : (305, 364)
# Centroid : (235, 265), farthest Point : (256, 394)
# Centroid : (235, 265), farthest Point : (256, 394)
# Centroid : (240, 266), farthest Point : (158, 373)
# Centroid : (247, 246), farthest Point : (250, 366)
# Centroid : (251, 252), farthest Point : (248, 393)
# Centroid : (244, 257), farthest Point : (257, 396)
# Centroid : (245, 251), farthest Point : (182, 352)
# Centroid : (235, 268), farthest Point : (246, 412)
# Centroid : (252, 262), farthest Point : (221, 390)
# Centroid : (238, 256), farthest Point : (182, 358)
# Centroid : (249, 246), farthest Point : (251, 367)
# Centroid : (245, 251), farthest Point : (245, 392)
# Centroid : (245, 251), farthest Point : (245, 392)
# Centroid : (250, 268), farthest Point : (135, 353)
# Centroid : (249, 260), farthest Point : (243, 395)
# Centroid : (253, 263), farthest Point : (177, 362)
# Centroid : (246, 257), farthest Point : (226, 407)
# Centroid : (247, 257), farthest Point : (245, 396)
# Centroid : (247, 248), farthest Point : (252, 366)
# Centroid : (250, 252), farthest Point : (188, 362)
# Centroid : (255, 267), farthest Point : (241, 406)
# Centroid : (241, 260), farthest Point : (240, 409)
# Centroid : (244, 262), farthest Point : (252, 394)
# Centroid : (253, 268), farthest Point : (214, 403)
# Centroid : (240, 278), farthest Point : (132, 377)
# Centroid : (249, 264), farthest Point : (309, 374)
# Centroid : (248, 254), farthest Point : (217, 391)
# Centroid : (237, 262), farthest Point : (247, 413)
# Centroid : (243, 262), farthest Point : (252, 393)
# Centroid : (254, 267), farthest Point : (264, 394)
# Centroid : (238, 263), farthest Point : (209, 402)
# Centroid : (250, 256), farthest Point : (250, 393)
# Centroid : (244, 264), farthest Point : (160, 370)
# Centroid : (244, 264), farthest Point : (160, 370)
# Centroid : (249, 252), farthest Point : (185, 351)
# Centroid : (256, 266), farthest Point : (244, 403)
# Centroid : (240, 254), farthest Point : (260, 396)
# Centroid : (253, 276), farthest Point : (208, 410)
# Centroid : (250, 251), farthest Point : (191, 353)
# Centroid : (248, 248), farthest Point : (232, 365)
# Centroid : (243, 262), farthest Point : (241, 393)
# Centroid : (251, 252), farthest Point : (181, 357)
# Centroid : (248, 264), farthest Point : (217, 408)
# Centroid : (248, 264), farthest Point : (217, 408)
# Centroid : (245, 258), farthest Point : (180, 368)
# Centroid : (244, 257), farthest Point : (249, 398)
# Centroid : (248, 250), farthest Point : (249, 367)
# Centroid : (250, 270), farthest Point : (207, 410)
# Centroid : (248, 264), farthest Point : (305, 363)
# Centroid : (249, 260), farthest Point : (217, 391)
# Centroid : (255, 260), farthest Point : (249, 393)
# Centroid : (274, 256), farthest Point : (405, 300)
# Centroid : (253, 247), farthest Point : (250, 366)
# Centroid : (252, 256), farthest Point : (183, 361)
# Centroid : (289, 277), farthest Point : (184, 196)
# Centroid : (289, 277), farthest Point : (184, 196)
# Centroid : (296, 273), farthest Point : (419, 217)
# Centroid : (272, 282), farthest Point : (138, 340)
# Centroid : (297, 263), farthest Point : (454, 259)
# Centroid : (292, 262), farthest Point : (154, 364)
# Centroid : (266, 265), farthest Point : (324, 115)
# Centroid : (249, 259), farthest Point : (128, 367)
# Centroid : (269, 256), farthest Point : (325, 114)
# Centroid : (270, 230), farthest Point : (269, 27)
# Centroid : (269, 254), farthest Point : (164, 367)
# Centroid : (271, 206), farthest Point : (280, 14)
# Centroid : (267, 215), farthest Point : (321, 24)
# Centroid : (267, 215), farthest Point : (321, 24)
# Centroid : (254, 255), farthest Point : (136, 381)
# Centroid : (249, 258), farthest Point : (326, 119)
# Centroid : (270, 209), farthest Point : (257, 0)
# Centroid : (265, 248), farthest Point : (321, 118)
# Centroid : (259, 218), farthest Point : (134, 382)
# Centroid : (267, 264), farthest Point : (126, 372)
# Centroid : (271, 247), farthest Point : (325, 115)
# Centroid : (265, 217), farthest Point : (270, 30)
# Centroid : (264, 254), farthest Point : (236, 414)
# Centroid : (268, 246), farthest Point : (324, 117)
# Centroid : (268, 246), farthest Point : (324, 117)
# Centroid : (262, 251), farthest Point : (325, 122)
# Centroid : (249, 261), farthest Point : (131, 385)
# Centroid : (268, 254), farthest Point : (324, 118)
# Centroid : (268, 250), farthest Point : (324, 118)
# Centroid : (263, 256), farthest Point : (327, 115)
# Centroid : (259, 220), farthest Point : (131, 378)
# Centroid : (245, 228), farthest Point : (313, 52)
# Centroid : (262, 293), farthest Point : (394, 355)
# Centroid : (287, 238), farthest Point : (263, 0)
# Centroid : (264, 256), farthest Point : (329, 120)
# Centroid : (260, 242), farthest Point : (330, 133)
# Centroid : (260, 242), farthest Point : (330, 133)
# Centroid : (260, 238), farthest Point : (229, 368)
# Centroid : (254, 246), farthest Point : (171, 368)
# Centroid : (260, 248), farthest Point : (241, 404)
# Centroid : (297, 246), farthest Point : (448, 291)
# Centroid : (259, 238), farthest Point : (232, 367)
# Centroid : (261, 241), farthest Point : (249, 368)
# Centroid : (278, 255), farthest Point : (425, 306)
# Centroid : (280, 252), farthest Point : (423, 304)
# Centroid : (247, 252), farthest Point : (159, 387)
# Centroid : (254, 251), farthest Point : (235, 396)
# Centroid : (258, 242), farthest Point : (232, 367)
# Centroid : (258, 242), farthest Point : (232, 367)
# Centroid : (281, 269), farthest Point : (208, 401)
# Centroid : (252, 253), farthest Point : (216, 408)
# Centroid : (253, 249), farthest Point : (159, 368)
# Centroid : (245, 257), farthest Point : (206, 413)
# Centroid : (271, 267), farthest Point : (120, 258)
# Centroid : (275, 271), farthest Point : (433, 267)
# Centroid : (287, 275), farthest Point : (168, 393)
# Centroid : (270, 271), farthest Point : (130, 154)
# Centroid : (274, 283), farthest Point : (132, 340)
# Centroid : (274, 283), farthest Point : (132, 340)
# Centroid : (270, 270), farthest Point : (147, 175)
# Centroid : (255, 266), farthest Point : (149, 161)
# Centroid : (258, 261), farthest Point : (147, 156)
# Centroid : (245, 251), farthest Point : (134, 138)
# Centroid : (239, 244), farthest Point : (98, 117)
# Centroid : (239, 252), farthest Point : (135, 107)
# Centroid : (254, 205), farthest Point : (247, 417)
# Centroid : (260, 209), farthest Point : (289, 32)
# Centroid : (272, 211), farthest Point : (345, 375)
# Centroid : (275, 203), farthest Point : (223, 26)
# Centroid : (282, 206), farthest Point : (174, 52)
# Centroid : (282, 206), farthest Point : (174, 52)
# Centroid : (291, 218), farthest Point : (233, 417)
# Centroid : (296, 219), farthest Point : (193, 36)
# Centroid : (310, 216), farthest Point : (217, 371)
# Centroid : (312, 219), farthest Point : (217, 415)
# Centroid : (309, 246), farthest Point : (212, 412)
# Centroid : (241, 255), farthest Point : (239, 398)
# Centroid : (240, 248), farthest Point : (238, 371)
# Centroid : (237, 255), farthest Point : (241, 396)
# Centroid : (235, 266), farthest Point : (192, 414)
# Centroid : (245, 249), farthest Point : (241, 369)
# Centroid : (238, 259), farthest Point : (158, 373)
# Centroid : (240, 265), farthest Point : (229, 408)
# Centroid : (242, 249), farthest Point : (241, 369)
# Centroid : (239, 256), farthest Point : (166, 367)
# Centroid : (236, 272), farthest Point : (253, 415)
# Centroid : (241, 273), farthest Point : (220, 411)
# Centroid : (242, 247), farthest Point : (236, 367)
# Centroid : (234, 267), farthest Point : (142, 378)
# Centroid : (241, 257), farthest Point : (209, 402)
# Centroid : (233, 261), farthest Point : (250, 414)
# Centroid : (241, 255), farthest Point : (232, 391)
# Centroid : (238, 263), farthest Point : (249, 413)
# Centroid : (252, 271), farthest Point : (219, 409)
# Centroid : (250, 265), farthest Point : (300, 370)
# Centroid : (240, 262), farthest Point : (176, 368)
# Centroid : (232, 265), farthest Point : (229, 413)
# Centroid : (234, 227), farthest Point : (124, 234)
# Centroid : (240, 225), farthest Point : (153, 237)
# Centroid : (257, 300), farthest Point : (403, 394)
# Centroid : (262, 297), farthest Point : (391, 380)
# Centroid : (259, 289), farthest Point : (385, 370)
# Centroid : (249, 276), farthest Point : (117, 206)
# Centroid : (256, 285), farthest Point : (129, 181)
# Centroid : (261, 276), farthest Point : (154, 167)
# Centroid : (256, 267), farthest Point : (138, 390)
# Centroid : (266, 258), farthest Point : (174, 124)
# Centroid : (269, 249), farthest Point : (127, 347)
# Centroid : (281, 225), farthest Point : (261, 34)
# Centroid : (284, 217), farthest Point : (196, 30)
# Centroid : (310, 214), farthest Point : (282, 21)
# Centroid : (307, 213), farthest Point : (246, 9)
# Centroid : (383, 226), farthest Point : (432, 329)
# Centroid : (219, 263), farthest Point : (154, 365)
# Centroid : (226, 259), farthest Point : (157, 382)
# Centroid : (233, 265), farthest Point : (286, 378)
# Centroid : (230, 252), farthest Point : (205, 370)
# Centroid : (228, 276), farthest Point : (206, 397)
# Centroid : (228, 251), farthest Point : (210, 370)
# Centroid : (226, 267), farthest Point : (220, 416)
# Centroid : (233, 264), farthest Point : (228, 394)
# Centroid : (234, 268), farthest Point : (201, 396)
# Centroid : (227, 250), farthest Point : (222, 369)
# Centroid : (228, 257), farthest Point : (161, 370)
# Centroid : (233, 259), farthest Point : (220, 413)
# Centroid : (231, 247), farthest Point : (227, 368)
# Centroid : (238, 265), farthest Point : (293, 373)
# Centroid : (234, 251), farthest Point : (210, 365)
# Centroid : (237, 251), farthest Point : (215, 366)
# Centroid : (226, 257), farthest Point : (144, 344)
# Centroid : (235, 254), farthest Point : (154, 338)
# Centroid : (241, 261), farthest Point : (293, 363)
# Centroid : (245, 260), farthest Point : (303, 378)
# Centroid : (246, 263), farthest Point : (220, 389)
# Centroid : (249, 265), farthest Point : (225, 392)
# Centroid : (242, 264), farthest Point : (251, 413)
# Centroid : (252, 269), farthest Point : (220, 389)
# Centroid : (246, 253), farthest Point : (246, 365)
# Centroid : (248, 264), farthest Point : (304, 367)
# Centroid : (249, 271), farthest Point : (162, 371)
# Centroid : (251, 269), farthest Point : (171, 385)
# Centroid : (249, 277), farthest Point : (283, 415)
# Centroid : (254, 279), farthest Point : (246, 411)
# Centroid : (245, 285), farthest Point : (137, 384)
# Centroid : (252, 279), farthest Point : (259, 413)
# Centroid : (253, 286), farthest Point : (283, 415)
# Centroid : (250, 281), farthest Point : (216, 408)
# Centroid : (247, 278), farthest Point : (265, 412)
# Centroid : (252, 274), farthest Point : (258, 410)
# Centroid : (251, 280), farthest Point : (265, 412)
# Centroid : (257, 280), farthest Point : (212, 411)
# Centroid : (251, 280), farthest Point : (265, 412)
# Centroid : (234, 286), farthest Point : (321, 178)
# Centroid : (233, 276), farthest Point : (262, 412)
# Centroid : (249, 284), farthest Point : (125, 340)
# Centroid : (248, 287), farthest Point : (215, 414)
# Centroid : (248, 287), farthest Point : (289, 418)
# Centroid : (252, 283), farthest Point : (217, 412)
# Centroid : (248, 289), farthest Point : (221, 423)
# Centroid : (246, 286), farthest Point : (325, 177)
# Centroid : (247, 288), farthest Point : (128, 365)
# Centroid : (247, 282), farthest Point : (263, 416)
# Centroid : (248, 281), farthest Point : (265, 416)
# Centroid : (247, 284), farthest Point : (263, 417)
# Centroid : (250, 287), farthest Point : (289, 420)
# Centroid : (265, 269), farthest Point : (264, 397)
# Centroid : (275, 253), farthest Point : (313, 371)
# Centroid : (204, 348), farthest Point : (142, 212)
# Centroid : (223, 320), farthest Point : (169, 117)
# Centroid : (237, 288), farthest Point : (317, 15)
# Centroid : (261, 265), farthest Point : (260, 17)
# Centroid : (283, 259), farthest Point : (309, 30)
# Centroid : (299, 244), farthest Point : (235, 36)
# Centroid : (312, 232), farthest Point : (190, 9)
# Centroid : (317, 231), farthest Point : (159, 387)
# Centroid : (321, 225), farthest Point : (206, 422)
# Centroid : (327, 217), farthest Point : (133, 360)
# Centroid : (323, 212), farthest Point : (131, 379)
# Centroid : (326, 219), farthest Point : (126, 374)
# Centroid : (328, 213), farthest Point : (161, 70)
# Centroid : (329, 217), farthest Point : (133, 370)
# Centroid : (327, 224), farthest Point : (204, 418)
# Centroid : (327, 216), farthest Point : (184, 419)
# Centroid : (326, 213), farthest Point : (128, 370)
# Centroid : (324, 213), farthest Point : (152, 367)
# Centroid : (325, 217), farthest Point : (126, 375)
# Centroid : (327, 215), farthest Point : (152, 375)
# Centroid : (325, 209), farthest Point : (449, 380)
# Centroid : (326, 214), farthest Point : (149, 368)
# Centroid : (325, 221), farthest Point : (124, 376)
# Centroid : (327, 220), farthest Point : (144, 369)
# Centroid : (326, 220), farthest Point : (129, 387)
# Centroid : (325, 213), farthest Point : (155, 394)
# Centroid : (327, 209), farthest Point : (212, 1)
# Centroid : (328, 218), farthest Point : (148, 365)
# Centroid : (327, 221), farthest Point : (133, 372)
# Centroid : (329, 219), farthest Point : (145, 392)
# Centroid : (329, 217), farthest Point : (148, 376)
# Centroid : (326, 215), farthest Point : (150, 374)
# Centroid : (324, 215), farthest Point : (128, 378)
# Centroid : (326, 215), farthest Point : (126, 369)
# Centroid : (330, 213), farthest Point : (161, 374)
# Centroid : (324, 215), farthest Point : (131, 380)
# Centroid : (329, 216), farthest Point : (410, 0)
# Centroid : (321, 215), farthest Point : (127, 369)
# Centroid : (326, 219), farthest Point : (416, 0)
# Centroid : (325, 216), farthest Point : (148, 371)
# Centroid : (324, 215), farthest Point : (131, 385)
# Centroid : (325, 218), farthest Point : (125, 375)
# Centroid : (330, 214), farthest Point : (419, 0)
# Centroid : (325, 224), farthest Point : (130, 379)
# Centroid : (324, 218), farthest Point : (417, 0)
# Centroid : (324, 213), farthest Point : (204, 414)
# Centroid : (319, 217), farthest Point : (416, 0)
# Centroid : (310, 227), farthest Point : (362, 4)
# Centroid : (302, 236), farthest Point : (317, 0)
# Centroid : (300, 241), farthest Point : (293, 23)
# Centroid : (290, 238), farthest Point : (235, 18)
# Centroid : (285, 243), farthest Point : (285, 17)
# Centroid : (278, 233), farthest Point : (227, 23)
# Centroid : (271, 242), farthest Point : (309, 39)
# Centroid : (270, 239), farthest Point : (321, 26)
# Centroid : (272, 262), farthest Point : (421, 315)
# Centroid : (266, 279), farthest Point : (425, 335)
# Centroid : (270, 275), farthest Point : (423, 350)
# Centroid : (268, 284), farthest Point : (411, 371)
# Centroid : (270, 297), farthest Point : (283, 479)
# Centroid : (264, 285), farthest Point : (414, 402)
# Centroid : (267, 304), farthest Point : (418, 410)
# Centroid : (269, 300), farthest Point : (411, 409)
# Centroid : (272, 306), farthest Point : (421, 414)
# Centroid : (265, 302), farthest Point : (411, 407)
# Centroid : (260, 266), farthest Point : (385, 381)
# Centroid : (277, 287), farthest Point : (431, 403)
# Centroid : (277, 284), farthest Point : (424, 396)
# Centroid : (266, 271), farthest Point : (429, 403)
# Centroid : (265, 279), farthest Point : (422, 399)
# Centroid : (265, 270), farthest Point : (430, 395)
# Centroid : (262, 272), farthest Point : (429, 398)
# Centroid : (257, 262), farthest Point : (382, 362)
# Centroid : (278, 285), farthest Point : (431, 392)
# Centroid : (263, 279), farthest Point : (433, 392)
# Centroid : (267, 264), farthest Point : (426, 389)
# Centroid : (271, 267), farthest Point : (435, 395)
# Centroid : (260, 269), farthest Point : (417, 393)
# Centroid : (253, 267), farthest Point : (375, 387)
# Centroid : (257, 288), farthest Point : (410, 415)
# Centroid : (254, 286), farthest Point : (402, 417)
# Centroid : (248, 279), farthest Point : (372, 399)
# Centroid : (253, 265), farthest Point : (389, 377)
# Centroid : (228, 246), farthest Point : (196, 365)
# Centroid : (222, 251), farthest Point : (205, 367)
# Centroid : (231, 267), farthest Point : (156, 372)
# Centroid : (226, 266), farthest Point : (280, 365)
# Centroid : (242, 289), farthest Point : (351, 455)
# Centroid : (230, 268), farthest Point : (292, 378)
# Centroid : (237, 275), farthest Point : (325, 375)
# Centroid : (223, 258), farthest Point : (222, 396)
# Centroid : (222, 255), farthest Point : (213, 390)
# Centroid : (223, 248), farthest Point : (221, 363)
# Centroid : (226, 254), farthest Point : (229, 390)
# Centroid : (226, 253), farthest Point : (231, 390)
# Centroid : (228, 249), farthest Point : (230, 361)
# Centroid : (229, 246), farthest Point : (231, 362)
# Centroid : (237, 259), farthest Point : (290, 357)
# Centroid : (236, 244), farthest Point : (239, 359)
# Centroid : (241, 243), farthest Point : (245, 355)
# Centroid : (247, 239), farthest Point : (251, 351)
# Centroid : (250, 242), farthest Point : (191, 346)
# Centroid : (258, 247), farthest Point : (272, 375)
# Centroid : (261, 246), farthest Point : (202, 345)
# Centroid : (267, 251), farthest Point : (289, 377)
# Centroid : (251, 252), farthest Point : (131, 276)
# Centroid : (267, 252), farthest Point : (341, 334)
# Centroid : (251, 258), farthest Point : (149, 351)
# Centroid : (259, 251), farthest Point : (153, 317)
# Centroid : (266, 257), farthest Point : (137, 314)
# Centroid : (264, 255), farthest Point : (161, 329)
# Centroid : (264, 252), farthest Point : (163, 330)
# Centroid : (270, 251), farthest Point : (166, 321)
# Centroid : (258, 257), farthest Point : (155, 380)
# Centroid : (263, 227), farthest Point : (274, 27)
# Centroid : (276, 246), farthest Point : (140, 248)
# Centroid : (267, 259), farthest Point : (189, 388)
# Centroid : (261, 262), farthest Point : (142, 374)
# Centroid : (262, 274), farthest Point : (233, 445)
# Centroid : (267, 214), farthest Point : (303, 34)
# Centroid : (260, 260), farthest Point : (110, 336)
# Centroid : (269, 254), farthest Point : (380, 180)
# Centroid : (263, 234), farthest Point : (202, 65)
# Centroid : (258, 231), farthest Point : (234, 437)
# Centroid : (264, 224), farthest Point : (271, 28)
# Centroid : (268, 217), farthest Point : (324, 53)
# Centroid : (266, 214), farthest Point : (273, 27)
# Centroid : (268, 223), farthest Point : (321, 52)
# Centroid : (269, 254), farthest Point : (158, 378)
# Centroid : (260, 215), farthest Point : (278, 13)
# Centroid : (266, 219), farthest Point : (207, 380)
# Centroid : (265, 281), farthest Point : (307, 458)
# Centroid : (269, 249), farthest Point : (277, 464)
# Centroid : (274, 252), farthest Point : (149, 311)
# Centroid : (270, 211), farthest Point : (261, 9)
# Centroid : (267, 287), farthest Point : (315, 464)
# Centroid : (267, 279), farthest Point : (306, 465)
# Centroid : (266, 218), farthest Point : (263, 10)
# Centroid : (261, 217), farthest Point : (158, 379)
# Centroid : (269, 281), farthest Point : (307, 465)
# Centroid : (265, 278), farthest Point : (300, 463)
# Centroid : (268, 235), farthest Point : (309, 464)
# Centroid : (265, 261), farthest Point : (133, 361)
# Centroid : (267, 226), farthest Point : (298, 66)
# Centroid : (268, 270), farthest Point : (231, 449)
# Centroid : (273, 257), farthest Point : (130, 310)
# Centroid : (267, 217), farthest Point : (268, 35)
# Centroid : (272, 218), farthest Point : (331, 27)
# Centroid : (274, 229), farthest Point : (319, 48)
# Centroid : (274, 214), farthest Point : (278, 27)
# Centroid : (261, 250), farthest Point : (187, 42)
# Centroid : (272, 214), farthest Point : (323, 0)
# Centroid : (272, 214), farthest Point : (299, 33)
# Centroid : (273, 218), farthest Point : (317, 48)
# Centroid : (268, 246), farthest Point : (262, 10)
# Centroid : (264, 236), farthest Point : (300, 466)
# Centroid : (268, 257), farthest Point : (153, 366)
# Centroid : (271, 257), farthest Point : (179, 377)
# Centroid : (263, 281), farthest Point : (310, 461)
# Centroid : (266, 217), farthest Point : (131, 384)
# Centroid : (265, 220), farthest Point : (319, 25)
# Centroid : (269, 251), farthest Point : (168, 349)
# Centroid : (261, 281), farthest Point : (315, 461)
# Centroid : (262, 211), farthest Point : (206, 20)
# Centroid : (267, 244), farthest Point : (153, 356)
# Centroid : (263, 243), farthest Point : (320, 462)
# Centroid : (263, 248), farthest Point : (124, 222)
# Centroid : (265, 214), farthest Point : (319, 25)
# Centroid : (267, 253), farthest Point : (380, 175)
# Centroid : (265, 212), farthest Point : (236, 30)
# Centroid : (265, 207), farthest Point : (298, 36)
# Centroid : (268, 247), farthest Point : (156, 334)
# Centroid : (264, 231), farthest Point : (314, 33)
# Centroid : (259, 246), farthest Point : (161, 350)
# Centroid : (249, 252), farthest Point : (155, 374)
# Centroid : (254, 253), farthest Point : (274, 384)
# Centroid : (246, 252), farthest Point : (139, 355)
# Centroid : (253, 250), farthest Point : (167, 143)
# Centroid : (247, 253), farthest Point : (156, 374)
# Centroid : (253, 250), farthest Point : (163, 332)
# Centroid : (244, 256), farthest Point : (151, 355)
# Centroid : (257, 262), farthest Point : (132, 372)
# Centroid : (253, 254), farthest Point : (340, 174)
# Centroid : (254, 255), farthest Point : (163, 349)
# Centroid : (248, 260), farthest Point : (126, 330)
# Centroid : (246, 264), farthest Point : (143, 344)
# Centroid : (253, 258), farthest Point : (138, 314)
# Centroid : (252, 256), farthest Point : (159, 341)
# Centroid : (239, 270), farthest Point : (332, 173)
# Centroid : (252, 266), farthest Point : (157, 367)
# Centroid : (244, 265), farthest Point : (142, 375)
# Centroid : (241, 262), farthest Point : (129, 330)
# Centroid : (251, 261), farthest Point : (150, 366)
# Centroid : (257, 257), farthest Point : (160, 327)
# Centroid : (236, 265), farthest Point : (128, 385)
# Centroid : (253, 256), farthest Point : (159, 329)
# Centroid : (250, 258), farthest Point : (336, 172)
# Centroid : (255, 256), farthest Point : (142, 338)
# Centroid : (250, 263), farthest Point : (132, 348)
# Centroid : (248, 262), farthest Point : (133, 337)
# Centroid : (255, 258), farthest Point : (162, 349)
# Centroid : (273, 258), farthest Point : (267, 388)
# Centroid : (242, 263), farthest Point : (135, 377)
# Centroid : (247, 264), farthest Point : (160, 370)
# Centroid : (247, 265), farthest Point : (156, 389)
# Centroid : (246, 258), farthest Point : (160, 357)
# Centroid : (252, 261), farthest Point : (159, 363)
# Centroid : (273, 249), farthest Point : (206, 346)
# Centroid : (252, 259), farthest Point : (144, 357)
# Centroid : (253, 265), farthest Point : (132, 364)
# Centroid : (252, 255), farthest Point : (341, 171)
# Centroid : (248, 263), farthest Point : (153, 366)
# Centroid : (245, 266), farthest Point : (156, 371)
# Centroid : (251, 260), farthest Point : (339, 173)
# Centroid : (250, 271), farthest Point : (129, 384)
