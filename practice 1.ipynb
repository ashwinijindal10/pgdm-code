# %%
import pandas as pd
marks = pd.read_csv('https://query.data.world/s/HqjNNadqEnwSq1qnoV_JqyRJkc7o6O')

# %%
#delete marks[marks.isna().sum(axis=1)==5]

print(marks[marks.isna().sum(axis=1)==5])

print(marks.isna().sum())

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

marks = pd.read_csv('Data//tendulkar_ODI.csv')

marks.head()

#remove do not bat

#marks[marks['Runs'].str.isnumeric() == False]


marks1=marks[marks['Runs'].str.isnumeric()]
marks2=marks[marks['4s'].str.isnumeric()]

#marks[marks['4s'].str.isnumeric()==False]
#len(marks1)
#len(marks)
plt.figure(figsize=[20,8])
plt.xlabel('Runs',fontsize=15)
plt.ylabel('Frequency',fontsize=15)
plt.xticks(fontsize=10)
plt.yticks(fontsize=15)

#plt.xticks(range(10))

#plt.hist(sorted(marks1['Runs']),bins=range(10), color='#0504aa',alpha=0.2, rwidth=0.85)

plt.hist(sorted(marks2['4s']), color='#0504aa')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('Data//popularity.csv')

data.head()

# %%
data.describe()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('Data//currencies.csv')

data.head()
# Out:
#         Currency  Chinese Yuan     Euro  Japanese Yen  U.K. Pound Sterling  \
# 0  July 01, 2016       9.29446  1.25367       143.645              1.05054
# 1  July 05, 2016       9.31515  1.25322       142.715              1.06143
# 2  July 06, 2016       9.31697  1.25834       140.540              1.07300
# 3  July 07, 2016       9.31315  1.25737       140.640              1.06911
# 4  July 08, 2016       9.31350  1.25797       140.510              1.07261
#
#    U.S. Dollar  Algerian Dinar  Australian Dollar  Bahrain Dinar  \
# 0      1.39596             NaN            1.87126       0.524882
# 1      1.39684         154.063            1.85825       0.525213
# 2      1.39286         154.094            1.87313       0.523717
# 3      1.39316         153.957            1.85236       0.523829
# 4      1.39257         154.062            1.85974       0.523607
#
#    Botswana Pula  ...  South African Rand  Sri Lanka Rupee  Swedish Krona  \
# ...

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(data.corr())
#plt.show()

corr = data.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# C:\Users\Ashwini\anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_90d18140_8d43_11ea_9c85_ecb1d7bd3bbarow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_90d18140_8d43_11ea_9c85_ecb1d7bd3bbarow0_col1 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_90d18140_8d43_11ea_9c85_ecb1d7bd3bbarow0_col2 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_90d18140_8d43_11ea_9c85_ecb1d7bd3bbarow0_col3 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_90d18140_8d43_11ea_9c85_ecb1d7bd3bbarow0_col4 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_90d18140_8d43_11ea_9c85_ecb1d7bd3bbarow0_col5 {
#             background-color:  #dc5d4a;
#             color:  #000000;
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('Data//Lending Club Case Study//loan.csv',low_memory=False)

# %%
data.count()

data.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %%
#no duplicate data
data[data.duplicated(['member_id'])]

data1=data[['member_id','loan_amnt','acc_now_delinq','delinq_amnt',
      'annual_inc','application_type' ,'loan_amnt','home_ownership','loan_status']]

data1
# Out:
#        member_id  loan_amnt  acc_now_delinq  delinq_amnt  annual_inc  \
# 0        1296599       5000               0            0     24000.0
# 1        1314167       2500               0            0     30000.0
# 2        1313524       2400               0            0     12252.0
# 3        1277178      10000               0            0     49200.0
# 4        1311748       3000               0            0     80000.0
# ...          ...        ...             ...          ...         ...
# 39712      92174       2500               0            0    110000.0
# 39713      90607       8500               0            0     18000.0
# 39714      90390       5000               0            0    100000.0
# 39715      89243       5000               0            0    200000.0
# 39716      86999       7500               0            0     22000.0
#
#       application_type  loan_amnt home_ownership  loan_status
# 0           INDIVIDUAL       5000           RENT   Fully Paid
# ...

# %%
#data1.shape
"""
avg_cur_bal         
bc_util             
emp_length          
inq_last_12m        
inq_fi       
annual_inc_joint    
tot_cur_bal         
tot_coll_amt
""" 
#chekck null 
data1.isnull().sum()

#chekc fully paid customer

#data_fullypaid=data1[data1['loan_status']=='Fully Paid']


data_2= data1[['home_ownership','loan_status']]

#data_fullypaid.groupby
#rs=pd.pivot_table(data1,columns=['loan_status'],index=['home_ownership'],values='home_ownership', aggfunc = 'count')

rs=pd.pivot_table(data_2, index =['home_ownership'], columns=['loan_status'], aggfunc=len, fill_value=0)


#data1.groupby(['home_ownership','loan_status']).sum()
#data1.pivot(index='loan_status', columns='home_ownership')
print(rs)
rs.plot.bar()
# Out:
# loan_status     Charged Off  Current  Fully Paid
# home_ownership
# MORTGAGE               2327      638       14694
# NONE                      0        0           3
# OTHER                    18        0          80
# OWN                     443       83        2532
# RENT                   2839      419       15641

# %%
column_1 = int(data_2["loan_status"])
column_2 = int(data_2["home_ownership"])

correlation = column_1.corr(column_2)

print(correlation)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-5e873dbb2e55> in <module>
# ----> 1 column_1 = int(data_2["loan_status"])
#       2 column_2 = int(data_2["home_ownership"])
#       3
#       4 correlation = column_1.corr(column_2)
#       5
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#     110         if len(self) == 1:
#     111             return converter(self.iloc[0])
# --> 112         raise TypeError(f"cannot convert the series to {converter}")
#     113
#     114     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'int'>
